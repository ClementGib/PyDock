# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import math

# %%
path = "/mnt/c/Users/Cleme/Documents/Python/Project_Py/data/sales_predictions.csv"
predictions = pd.read_csv(path,sep=",")

# %%
predictions.head
# Out:
# <bound method NDFrame.head of                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...

# %%
predictions.columns

# %%
x=predictions['date']
y=predictions['item_price']

sb.set(style="ticks")

g = sb.relplot(x="date", y="item_price", data=predictions)

# %%
sb.set(style="ticks")
g = sb.relplot(x="date", y="item_price", sizes=(20,6),data=predictions.sample(n=50))
#il ne sait pas interpréter les date en string se qui affiche une bande noir

# %%
predictions["date"] = pd.to_datetime(predictions["date"])

print(predictions.dtypes)
# Out:
# date              datetime64[ns]
# date_block_num             int64
# shop_id                    int64
# item_id                    int64
# item_price               float64
# item_cnt_day             float64
# dtype: object

# %%
x=predictions['date']
y=predictions['item_price']
print(x_date)

sb.set(style="ticks")
g = sb.relplot(x="date", y="item_price", sizes=(20,6),data=predictions.sample(n=50))
# Out:
# 0          02.01.2013
# 1          03.01.2013
# 2          05.01.2013
# 3          06.01.2013
# 4          15.01.2013
#               ...
# 2935844    10.10.2015
# 2935845    09.10.2015
# 2935846    14.10.2015
# 2935847    22.10.2015
# 2935848    03.10.2015
# Name: date, Length: 2935849, dtype: object
